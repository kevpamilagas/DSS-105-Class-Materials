# %% [markdown]
# # Import required libraries

# %%
import numpy as np #for linear algebra
import pandas as pd #for data manipulation

import matplotlib.pyplot as plt #data visualization
import seaborn as sns #advanced visualiation

# %%
sns.set() #uses sns skins for matplotlib visualizations

# %% [markdown]
# # Read in new .csv as Pandas DataFrame

# %%
store = pd.read_csv('Store 7141 Raw Data (clean).csv')
store.head()
# Out:
#           Trans_id  Menu_id  Sand_id  Employees  Bread_CT  Cheese_CT  \
# 0  7141.42739.4326        1        2          1        40         41
# 1  7141.42739.4535        6        2          1        45         43
# 2  7141.42739.4556        4        1          1        80         32
# 3  7141.42739.4625        3        2          1        44         60
# 4  7141.42739.4625        7        1          2        40         20
#
#    Protein_CT  Produce_CT  Wrap_CT  Payment_CT  ...  Quality Grade   Date  \
# 0          18          71       21          39  ...       32    81  42739
# 1          21          52       19          51  ...       18    73  42739
# 2          25          16       17          27  ...       32    63  42739
# 3          14          49       21          81  ...       26    38  42739
# 4          17          68       12          52  ...       20    56  42739
#
#      Time                       DateTime    Month    Shift Store      Sand  \
# 0  0.4326  2017-01-04 10:22:56.640000000  January  Morning  7141  Cold Cut
# 1  0.4535  2017-01-04 10:53:02.400000000  January  Morning  7141     Steak
# 2  0.4556  2017-01-04 10:56:03.840000000  January  Morning  7141  Meatball
# 3  0.4625  2017-01-04 11:06:00.000000000  January    Lunch  7141   Italian
# 4  0.4625  2017-01-04 11:06:00.000000000  January    Lunch  7141  Pastrami
#
#       Size
# 0  12-inch
# 1  12-inch
# 2   6-inch
# 3  12-inch
# 4   6-inch
#
# [5 rows x 32 columns]

# %% [markdown]
# # Scatterplot of relationship

# %%
sns.scatterplot(data = store.sample(1000), x = 'Payment_CT', y = 'Wait')
plt.xlabel('Payment Cycle')
plt.ylabel('Wait')
plt.title("Scatterplot: 'Payment' vs. 'Wait'")

print()

# %% [markdown]
# # Model Creation

# %%
import statsmodels.formula.api as smf

# %%
equation_1 = 'Wait ~ Payment_CT' #for more complex models, we can add additional columns using the '+' symbol

# %%
model_1 = smf.ols(equation_1, store).fit()
model_1

# %% [markdown]
# # Understanding the Slope and Y-Intercept

# %%
model_1.params
# Out:
# Intercept     16.846581
# Payment_CT    -0.219551
# dtype: float64

# %%
intercept = model_1.params['Intercept']
intercept
# Out:
# np.float64(16.846580925984433)

# %%
slope = model_1.params['Payment_CT']
slope
# Out:
# np.float64(-0.21955060163844597)

# %%
60 * slope + intercept #this m * x + b
# Out:
# np.float64(3.6735448276776754)

# %%
print(store['Payment_CT'].min())
print(store['Payment_CT'].max())
# Out:
# -47
# 241

# %%
print(5 * slope + intercept) #this is the output if we use the minimum
print(228 * slope + intercept) #this is the output if we use the maximum
# Out:
# 15.748827917792203
# -33.21095624758125

# %%
print(store['Wait'].max())
print(store['Wait'].min())
# Out:
# 35
# -50

# %%
y_pred = model_1.predict(store)
y_pred
# Out:
# 0         8.284107
# 1         5.649500
# 2        10.918715
# 3        -0.937018
# 4         5.429950
#            ...
# 50842     9.381860
# 50843     7.405905
# 50844    10.479613
# 50845     8.503658
# 50846     8.503658
# Length: 50847, dtype: float64

# %% [markdown]
# # Plotting the model

# %%
data_samp = store.sample(1000)
wait_pred = model_1.predict(data_samp)

sns.scatterplot(data = data_samp, x = 'Payment_CT', y = 'Wait')
plt.xlabel('Payment Cycle')
plt.ylabel('Wait')
plt.title("Scatterplot: 'Payment Cycle' vs. 'Wait'")

plt.plot(data_samp['Payment_CT'], wait_pred, color = 'red')
plt.text(0,-35,f'y = {slope: 2f}*x + {intercept: 2f}')

print()

# %% [markdown]
# # Model performance

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Wait   R-squared:                       0.486
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                 4.814e+04
# Date:                Fri, 06 Mar 2026   Prob (F-statistic):               0.00
# Time:                        10:40:29   Log-Likelihood:            -1.9509e+05
# No. Observations:               50847   AIC:                         3.902e+05
# Df Residuals:                   50845   BIC:                         3.902e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     16.8466      0.119    141.002      0.000      16.612      17.081
# Payment_CT    -0.2196      0.001   -219.409      0.000      -0.222      -0.218
# ==============================================================================
# Omnibus:                     2233.499   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2509.289
# Skew:                           0.537   Prob(JB):                         0.00
# Kurtosis:                       2.828   Cond. No.                         287.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_1.pvalues #check if this value is <.05
# Out:
# Intercept     0.0
# Payment_CT    0.0
# dtype: float64

# %%
model_1.pvalues['Payment_CT']
# Out:
# np.float64(0.0)

# %%
model_1.rsquared #this accounts for the % of variability that's explained by our model
# Out:
# np.float64(0.486337191082283)

# %%
np.sqrt(model_1.mse_resid) #average error of our model
# Out:
# np.float64(11.222700100190297)

# %% [markdown]
# # Formatting

# %%
print("Model Results ('Payment_CT' vs. 'Wait'):")
print(f"   Intercept: {model_1.params['Intercept']: .2f}")
print(f"   Slope: {model_1.params['Payment_CT']: .2f}")
print(f"   P-Value: {model_1.pvalues['Payment_CT']: .2f}")
print(f"   R-Squared: {model_1.rsquared: .2f}")
print(f"   Standard Error: {np.sqrt(model_1.mse_resid): .2f}")

data_samp = store.sample(1000)
wait_pred = model_1.predict(data_samp)

sns.scatterplot(data = data_samp, x = 'Payment_CT', y = 'Wait')
plt.xlabel('Payment Cycle')
plt.ylabel('Wait')
plt.title("Scatterplot: 'Payment Cycle' vs. 'Wait'")

plt.plot(data_samp['Payment_CT'], wait_pred, color = 'red')

print()
# Out:
# Model Results ('Payment_CT' vs. 'Wait'):
#    Intercept:  16.85
#    Slope: -0.22
#    P-Value:  0.00
#    R-Squared:  0.49
#    Standard Error:  11.22

# %% [markdown]
# # Python Exercise 7:

# %%
ind = 'Payment_CT'
dep = 'Wait'
data = store

#edit everything below with intended changes:

#***create model***
equation_1 = f'{dep} ~ {ind}'
model_1 = smf.ols(equation_1, store).fit()

#***save calculated statistics***
intercept = model_1.params['Intercept']
slope = model_1.params[ind]
p_value = model_1.pvalues[ind]
r_sq = model_1.rsquared
std_er = np.sqrt(model_1.mse_resid)

#***format statistics output***
print(f"Model Results ({ind} vs. {dep}):")
print(f"   Intercept: {intercept: .2f}")
print(f"   Slope: {slope: .2f}")
print(f"   P-Value: {p_value: .2f}")
print(f"   R-Squared: {r_sq: .2f}")
print(f"   Standard Error: {std_er: .2f}")

#***plot model against data***
data_samp = store.sample(1000)
wait_pred = model_1.predict(data_samp)

sns.scatterplot(data = data_samp, x = ind, y = dep)
plt.xlabel(f'{ind}')
plt.ylabel(f'{dep}')
plt.title(f"Scatterplot: '{ind}' vs. '{dep}'")

plt.plot(data_samp[ind], wait_pred, color = 'red')

print()
# Out:
# Model Results (Payment_CT vs. Wait):
#    Intercept:  16.85
#    Slope: -0.22
#    P-Value:  0.00
#    R-Squared:  0.49
#    Standard Error:  11.22

# %% [markdown]
# ## Cleaner version of Exercise 7:

# %%
# Create simple linear regression for each of the process times vs. the wait rating.
def model_prediction(ind, dep, data):

    equation = f'{dep} ~ {ind}'
    model = smf.ols(equation, data).fit()
    
    print(f"Model Results ('{ind}' vs. '{dep}'):")
    print(f"   Intercept: {model.params['Intercept']: .2f}")
    print(f"   Slope: {model.params[ind]: .2f}")
    print(f"   P-Value: {model.pvalues[ind]: .2f}")
    print(f"   R-Squared: {model.rsquared: .2f}")
    print(f"   Standard Error: {np.sqrt(model.mse_resid): .2f}")
    
    data_samp = data.sample(1000)
    pred = model.predict(data_samp)
    
    sns.scatterplot(data = data_samp, x = ind, y = dep)
    plt.xlabel(ind)
    plt.ylabel(dep)
    plt.title(f"Scatterplot: '{ind}' vs. '{dep}'")
    
    plt.plot(data_samp[ind], pred, color = 'red')
    
    print()

# %%
model_prediction('Payment_CT', 'Wait', store)
# Out:
# Model Results ('Payment_CT' vs. 'Wait'):
#    Intercept:  16.85
#    Slope: -0.22
#    P-Value:  0.00
#    R-Squared:  0.49
#    Standard Error:  11.22

# %%
equation = 'Wait ~ Payment_CT'
model = smf.ols(equation, store).fit()

# %%
model.params
# Out:
# Intercept     16.846581
# Payment_CT    -0.219551
# dtype: float64

# %%
#note that our equation is 'y = m * x + b'
#written a different way: 'x = (y - b) / m'
print(f"Current payment cycle: {store['Payment_CT'].mean(): .2f}")
print(f"Target payment cycle is: {(12 - model.params['Intercept']) / model.params['Payment_CT']: .2f}")
# Out:
# Current payment cycle:  108.55
# Target payment cycle is:  22.08

# %%
pd.get_dummies(store, columns = ['Shift'])
# Out:
#               Trans_id  Menu_id  Sand_id  Employees  Bread_CT  Cheese_CT  \
# 0      7141.42739.4326        1        2          1        40         41
# 1      7141.42739.4535        6        2          1        45         43
# 2      7141.42739.4556        4        1          1        80         32
# 3      7141.42739.4625        3        2          1        44         60
# 4      7141.42739.4625        7        1          2        40         20
# ...                ...      ...      ...        ...       ...        ...
# 50842  7141.43100.8813        7        1          2        31         29
# 50843  7141.43100.8847        1        2          1        52         27
# 50844  7141.43100.8882        4        1          2        55         27
# 50845  7141.43100.8889        2        2          1        48         38
# 50846  7141.43100.8958        5        1          1        41         27
#
#        Protein_CT  Produce_CT  Wrap_CT  Payment_CT  ...  \
# 0              18          71       21          39  ...
# 1              21          52       19          51  ...
# 2              25          16       17          27  ...
# 3              14          49       21          81  ...
# 4              17          68       12          52  ...
# ...           ...         ...      ...         ...  ...
# 50842          20          55       14          34  ...
# 50843          17          42       21          43  ...
# 50844          17          39       12          29  ...
# 50845          18         124       16          38  ...
# 50846           6          37       18          38  ...
#
#                             DateTime     Month Store      Sand     Size  \
# 0      2017-01-04 10:22:56.640000000   January  7141  Cold Cut  12-inch
# 1      2017-01-04 10:53:02.400000000   January  7141     Steak  12-inch
# 2      2017-01-04 10:56:03.840000000   January  7141  Meatball   6-inch
# 3      2017-01-04 11:06:00.000000000   January  7141   Italian  12-inch
# 4      2017-01-04 11:06:00.000000000   January  7141  Pastrami   6-inch
# ...                              ...       ...   ...       ...      ...
# 50842  2017-12-31 21:09:04.320000000  December  7141  Pastrami   6-inch
# 50843  2017-12-31 21:13:58.080000000  December  7141  Cold Cut  12-inch
# 50844  2017-12-31 21:19:00.480000000  December  7141  Meatball   6-inch
# 50845  2017-12-31 21:20:00.960000000  December  7141       BLT  12-inch
# 50846  2017-12-31 21:29:57.120000000  December  7141   Chicken   6-inch
#
#       Shift_Dinner Shift_Evening Shift_Lunch Shift_Mid-Day  Shift_Morning
# 0            False         False       False         False           True
# 1            False         False       False         False           True
# 2            False         False       False         False           True
# 3            False         False        True         False          False
# 4            False         False        True         False          False
# ...            ...           ...         ...           ...            ...
# 50842        False          True       False         False          False
# 50843        False          True       False         False          False
# 50844        False          True       False         False          False
# 50845        False          True       False         False          False
# 50846        False          True       False         False          False
#
# [50847 rows x 36 columns]

# %% [markdown]
# # Python Exercise 8:

# %%
def split_data(data):
    data_shuffled = data.sample(frac=1)

        # Calculate the indices for splitting
    train_end = int(0.6 * len(data_shuffled))
    val_end = int(0.2 * len(data_shuffled)) + train_end

    # Split the dataframe
    train = data_shuffled[:train_end]
    test = data_shuffled[train_end:val_end]
    validate = data_shuffled[val_end:]

    return train, test, validate

# %%
train, test, validate = split_data(store)
print(store.shape)
print(train.shape)
print(test.shape)
print(validate.shape)
# Out:
# (50847, 32)
# (30508, 32)
# (10169, 32)
# (10170, 32)
