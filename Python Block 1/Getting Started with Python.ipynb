# %% [markdown]
# # Getting Started with Python
#
# ## Learning Objectives
#
# By the end of this lesson, you should be able to:
#
# 1. **Navigate the Jupyter notebook environment** — run code cells, switch between command and edit mode, use keyboard shortcuts (Shift+Enter, A/B, DD, M/Y), and write basic markdown
# 2. **Identify and use basic data types** — integers, floats, strings, and booleans — and check types using `type()`
# 3. **Create and manipulate core data structures** — lists, sets, tuples, and dictionaries — and distinguish when to use each
# 4. **Apply Python operators** — arithmetic (`+`, `*`, `**`, `%`), comparison (`==`, `!=`, `>`, `<`), logical (`and`, `or`, `not`), and membership (`in`)
# 5. **Write conditional logic** — use `if`/`elif`/`else` statements to control program flow
# 6. **Iterate with loops** — use `for` and `while` loops to repeat operations over data

# %% [markdown]
# # Jupyter Notebook Environment
#
# ## Cell Basics
# - **Run a cell:** Shift+Enter (runs current cell and moves to next)
# - **Cell types:** Code cells run Python; Markdown cells render formatted text
# - **Toggle cell type:** M for markdown, Y for code (must be in command mode)
#
# ## Command Mode vs. Edit Mode
# - **Command mode** (blue border): Navigate and manipulate cells — press Escape to enter
# - **Edit mode** (green border): Type inside a cell — press Enter or click into a cell
#
# ## Keyboard Shortcuts (Command Mode)
# | Shortcut | Action |
# |---|---|
# | A | Insert cell above |
# | B | Insert cell below |
# | DD | Delete selected cell |
# | M | Change cell to markdown |
# | Y | Change cell to code |
# | Shift+Enter | Run cell |
#
# ## Other Useful Features
# - **Show line numbers:** View > Show Line Numbers
# - **Kernel:** The Python "brain" behind the notebook — shut down or restart if things freeze (Kernel > Shutdown/Restart)

# %% [markdown]
# ## Markdown

# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Defining a Variable

# %% [markdown]
# ## Numbers

# %% [markdown]
# ## Strings

# %% [markdown]
# ## Booleans

# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Lists

# %% [markdown]
# ## Sets

# %% [markdown]
# ## Tuples

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# # Operators

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# ## String Arithmetic

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# ## Logic Operators

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ## If/Else statements

# %% [markdown]
# # Loops

# %% [markdown]
# ## For Loop

# %% [markdown]
# ## While loops

# %% [markdown]
# # Summary
#
# ## What We Covered
#
# | Topic | Key Takeaways |
# |---|---|
# | **Jupyter Environment** | Shift+Enter to run, A/B to add cells, DD to delete, M/Y to toggle markdown/code, command mode vs. edit mode |
# | **Data Types** | `int`, `float`, `str`, `bool` — use `type()` to check |
# | **Data Structures** | **Lists** `[]` — ordered, mutable · **Sets** `{}` — unique, unordered · **Tuples** `()` — immutable · **Dictionaries** `{key: value}` — key-value pairs with unique keys |
# | **Operators** | Arithmetic (`+`, `-`, `*`, `**`, `/`, `%`) · Comparison (`==`, `!=`, `>`, `<`) · Logical (`and`, `or`, `not`) · Membership (`in`) |
# | **Control Flow** | `if`/`elif`/`else` — indentation matters! |
# | **Loops** | `for` — iterate over data structures · `while` — repeat until a condition is false |
#
# ## Key Reminders
# - `=` is **assignment**, `==` is **comparison**
# - `True`/`False` must be capitalized
# - Python uses **indentation** (not braces) to define code blocks
# - Variable names cannot start with a number
# - `print()` always displays output; without it, only the last line of a cell displays
